# %% [markdown]
# # The Deep Learning Project
#
# Team members:
# - Mellissa HAFIS
# - Ilona LEDROGOFF

# %%
# !wget https://www.lamsade.dauphine.fr/~cazenave/project2026.zip
# !unzip project2026.zip
# !ls -l
# Out:
# --2026-01-21 18:31:33--  https://www.lamsade.dauphine.fr/~cazenave/project2026.zip
# Resolving www.lamsade.dauphine.fr (www.lamsade.dauphine.fr)... 193.48.71.250
# Connecting to www.lamsade.dauphine.fr (www.lamsade.dauphine.fr)|193.48.71.250|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 138578548 (132M) [application/zip]
# Saving to: ‘project2026.zip’
#
# project2026.zip     100%[===================>] 132.16M  15.8MB/s    in 8.9s
#
# 2026-01-21 18:31:43 (14.8 MB/s) - ‘project2026.zip’ saved [138578548/138578548]
#
# Archive:  project2026.zip
#   inflating: games.data
#   inflating: golois.cpython-312-x86_64-linux-gnu.so
# total 665408
# -rw-r--r-- 1 root root 542497580 Oct  7  2022 games.data
# -rwxr-xr-x 1 root root    284672 Oct  1 15:09 golois.cpython-312-x86_64-linux-gnu.so
# -rw-r--r-- 1 root root 138578548 Oct  1 20:02 project2026.zip
# drwxr-xr-x 1 root root      4096 Dec  9 14:42 sample_data

# %% [markdown]
# ## Some improvements:
# ### In the feature extractor:
# - We change the simple Conv2D into residual blocks
# - It's supposed to help the network to reuse the features efficiently and prevent gradient vanishing problem.
#
# ### Adding a dropout in the value head
# - To prevent overfitting
#
# ### Increasing the number of filters
# - possible values: 35, 40, 45, 48, ...
# - MAX PARMS: 100 000
#
# ### Ajouter une mini-conv avant les têtes

# %%
import tensorflow as tf
import tensorflow.keras as keras
import numpy as np
from tensorflow.keras import layers
from tensorflow.keras import regularizers
import gc

import golois

planes = 31
moves = 361
N = 50000
epochs = 40
batch = 128
filters = 32

input_data = np.random.randint(2, size=(N, 19, 19, planes))
input_data = input_data.astype ('float32')

policy = np.random.randint(moves, size=(N,))
policy = keras.utils.to_categorical (policy)
policy = policy.astype ('float32')

value = np.random.randint(2, size=(N,))
value = value.astype ('float32')

end = np.random.randint(2, size=(N, 19, 19, 2))
end = end.astype ('float32')

groups = np.zeros((N, 19, 19, 1))
groups = groups.astype ('float32')

print ("Tensorflow version", tf.__version__)
print ("getValidation", flush = True)
golois.getValidation (input_data, policy, value, end)


def residual_block(x, filters):
    shortcut = x
    x = layers.Conv2D(filters, 3, padding='same', activation='relu')(x)
    x = layers.Conv2D(filters, 3, padding='same')(x)
    x = layers.Add()([x, shortcut])
    x = layers.Activation('relu')(x)
    return x

# features extractor

input = keras.Input(shape=(19, 19, planes), name='board')

x = layers.Conv2D(filters, 1, activation='relu', padding='same')(input)
for i in range(5):  # 5 residuel blocks
    x = residual_block(x, filters)


# policy head
policy_head = layers.Conv2D(2, 1, activation='relu', padding='same')(x)
policy_head = layers.Conv2D(1, 1, activation='relu', padding='same', use_bias = False, kernel_regularizer=regularizers.l2(0.0001))(policy_head)
policy_head = layers.Flatten()(policy_head)
policy_head = layers.Activation('softmax', name='policy')(policy_head)

# value head
value_head = layers.Conv2D(2, 1, activation='relu', padding='same')(x)
value_head = layers.Conv2D(1, 1, activation='relu', padding='same', use_bias = False, kernel_regularizer=regularizers.l2(0.0001))(value_head)
value_head = layers.Flatten()(value_head)
value_head = layers.Dense(50, activation='relu', kernel_regularizer=regularizers.l2(0.001))(value_head)
value_head = layers.Dropout(0.3)(value_head)
value_head = layers.Dense(1, activation='sigmoid', name='value', kernel_regularizer=regularizers.l2(0.0001))(value_head)

model = keras.Model(inputs=input, outputs=[policy_head, value_head])

model.summary ()

# compilation
model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.0001),
              loss={'policy': 'categorical_crossentropy', 'value': 'mse'},
              loss_weights={'policy' : 1.0, 'value' : 1.0},
              metrics={'policy': 'categorical_accuracy', 'value': 'mae'})

# training
for i in range (1, epochs + 1):
    print ('epoch ' + str (i))
    golois.getBatch (input_data, policy, value, end, groups, i * N)
    history = model.fit(input_data,
                        [policy,value],
                        epochs=1, batch_size=batch)
    if (i % 5 == 0):
        gc.collect ()
    if (i % 20 == 0):
        golois.getValidation (input_data, policy, value, end)
        val = model.evaluate (input_data,
                              [policy, value], verbose = 0, batch_size=batch)
        print ("val =", val)
        model.save ('test.keras')
# Out:
# Tensorflow version 2.19.0
# getValidation
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ board (InputLayer)  │ (None, 19, 19,    │          0 │ -                 │
# │                     │ 31)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 19, 19,    │      1,024 │ board[0][0]       │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 19, 19,    │      9,248 │ conv2d[0][0]      │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 19, 19,    │      9,248 │ conv2d_1[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 19, 19,    │          0 │ conv2d_2[0][0],   │
# │                     │ 32)               │            │ conv2d[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 19, 19,    │          0 │ add[0][0]         │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 19, 19,    │      9,248 │ activation[0][0]  │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 19, 19,    │      9,248 │ conv2d_3[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 19, 19,    │          0 │ conv2d_4[0][0],   │
# │                     │ 32)               │            │ activation[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 19, 19,    │          0 │ add_1[0][0]       │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 19, 19,    │      9,248 │ activation_1[0][… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 19, 19,    │      9,248 │ conv2d_5[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 19, 19,    │          0 │ conv2d_6[0][0],   │
# │                     │ 32)               │            │ activation_1[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 19, 19,    │          0 │ add_2[0][0]       │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 19, 19,    │      9,248 │ activation_2[0][… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 19, 19,    │      9,248 │ conv2d_7[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 19, 19,    │          0 │ conv2d_8[0][0],   │
# │                     │ 32)               │            │ activation_2[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 19, 19,    │          0 │ add_3[0][0]       │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 19, 19,    │      9,248 │ activation_3[0][… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 19, 19,    │      9,248 │ conv2d_9[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 19, 19,    │          0 │ conv2d_10[0][0],  │
# │                     │ 32)               │            │ activation_3[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 19, 19,    │          0 │ add_4[0][0]       │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 19, 19, 2) │         66 │ activation_4[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 19, 19, 1) │          2 │ conv2d_13[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 19, 19, 2) │         66 │ activation_4[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_1 (Flatten) │ (None, 361)       │          0 │ conv2d_14[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 19, 19, 1) │          2 │ conv2d_11[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 50)        │     18,100 │ flatten_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 361)       │          0 │ conv2d_12[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 50)        │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ policy (Activation) │ (None, 361)       │          0 │ flatten[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ value (Dense)       │ (None, 1)         │         51 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 111,791 (436.68 KB)
#  Trainable params: 111,791 (436.68 KB)
#  Non-trainable params: 0 (0.00 B)
# epoch 1
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 22s 30ms/step - loss: 5.5597 - policy_categorical_accuracy: 0.0236 - policy_loss: 5.3685 - value_loss: 0.1206 - value_mae: 0.2936
# epoch 2
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - loss: 4.3323 - policy_categorical_accuracy: 0.1366 - policy_loss: 4.1879 - value_loss: 0.1191 - value_mae: 0.2905
# epoch 3
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - loss: 4.0724 - policy_categorical_accuracy: 0.1651 - policy_loss: 3.9441 - value_loss: 0.1202 - value_mae: 0.2924
# epoch 4
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - loss: 3.8656 - policy_categorical_accuracy: 0.1889 - policy_loss: 3.7426 - value_loss: 0.1207 - value_mae: 0.2934
# epoch 5
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - loss: 3.7554 - policy_categorical_accuracy: 0.2032 - policy_loss: 3.6336 - value_loss: 0.1211 - value_mae: 0.2940
# epoch 6
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - loss: 3.6270 - policy_categorical_accuracy: 0.2254 - policy_loss: 3.5061 - value_loss: 0.1205 - value_mae: 0.2932
# epoch 7
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - loss: 3.5347 - policy_categorical_accuracy: 0.2415 - policy_loss: 3.4135 - value_loss: 0.1209 - value_mae: 0.2940
# epoch 8
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - loss: 3.4740 - policy_categorical_accuracy: 0.2492 - policy_loss: 3.3532 - value_loss: 0.1206 - value_mae: 0.2929
# epoch 9
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - loss: 3.3953 - policy_categorical_accuracy: 0.2621 - policy_loss: 3.2746 - value_loss: 0.1204 - value_mae: 0.2929
# epoch 10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - loss: 3.3540 - policy_categorical_accuracy: 0.2678 - policy_loss: 3.2342 - value_loss: 0.1195 - value_mae: 0.2915
# epoch 11
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - loss: 3.3169 - policy_categorical_accuracy: 0.2740 - policy_loss: 3.1955 - value_loss: 0.1211 - value_mae: 0.2940
# epoch 12
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - loss: 3.2731 - policy_categorical_accuracy: 0.2781 - policy_loss: 3.1516 - value_loss: 0.1212 - value_mae: 0.2942
# epoch 13
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - loss: 3.2550 - policy_categorical_accuracy: 0.2849 - policy_loss: 3.1343 - value_loss: 0.1205 - value_mae: 0.2934
# epoch 14
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - loss: 3.2187 - policy_categorical_accuracy: 0.2940 - policy_loss: 3.0982 - value_loss: 0.1203 - value_mae: 0.2926
# epoch 15
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - loss: 3.2210 - policy_categorical_accuracy: 0.2909 - policy_loss: 3.1009 - value_loss: 0.1199 - value_mae: 0.2924
# epoch 16
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - loss: 3.1917 - policy_categorical_accuracy: 0.2951 - policy_loss: 3.0709 - value_loss: 0.1206 - value_mae: 0.2933
# epoch 17
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - loss: 3.1482 - policy_categorical_accuracy: 0.2989 - policy_loss: 3.0261 - value_loss: 0.1220 - value_mae: 0.2952
# epoch 18
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - loss: 3.1510 - policy_categorical_accuracy: 0.3027 - policy_loss: 3.0312 - value_loss: 0.1196 - value_mae: 0.2918
# epoch 19
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - loss: 3.1327 - policy_categorical_accuracy: 0.3023 - policy_loss: 3.0125 - value_loss: 0.1200 - value_mae: 0.2920
# epoch 20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - loss: 3.1156 - policy_categorical_accuracy: 0.3047 - policy_loss: 2.9957 - value_loss: 0.1196 - value_mae: 0.2917
# val = [3.112736225128174, 2.9922399520874023, 0.12023411691188812, 0.3078800141811371, 0.29251039028167725]
# epoch 21
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - loss: 3.1108 - policy_categorical_accuracy: 0.3029 - policy_loss: 2.9901 - value_loss: 0.1205 - value_mae: 0.2932
# epoch 22
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - loss: 3.0864 - policy_categorical_accuracy: 0.3106 - policy_loss: 2.9667 - value_loss: 0.1195 - value_mae: 0.2917
# epoch 23
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - loss: 3.0922 - policy_categorical_accuracy: 0.3095 - policy_loss: 2.9722 - value_loss: 0.1198 - value_mae: 0.2919
# epoch 24
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - loss: 3.0694 - policy_categorical_accuracy: 0.3123 - policy_loss: 2.9491 - value_loss: 0.1202 - value_mae: 0.2927
# epoch 25
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - loss: 3.0670 - policy_categorical_accuracy: 0.3144 - policy_loss: 2.9451 - value_loss: 0.1217 - value_mae: 0.2955
# epoch 26
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - loss: 3.0478 - policy_categorical_accuracy: 0.3160 - policy_loss: 2.9277 - value_loss: 0.1199 - value_mae: 0.2919
# epoch 27
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - loss: 3.0513 - policy_categorical_accuracy: 0.3171 - policy_loss: 2.9310 - value_loss: 0.1201 - value_mae: 0.2922
# epoch 28
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - loss: 3.0281 - policy_categorical_accuracy: 0.3180 - policy_loss: 2.9070 - value_loss: 0.1209 - value_mae: 0.2938
# epoch 29
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - loss: 3.0194 - policy_categorical_accuracy: 0.3207 - policy_loss: 2.8988 - value_loss: 0.1204 - value_mae: 0.2929
# epoch 30
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - loss: 3.0257 - policy_categorical_accuracy: 0.3161 - policy_loss: 2.9048 - value_loss: 0.1208 - value_mae: 0.2934
# epoch 31
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - loss: 3.0137 - policy_categorical_accuracy: 0.3177 - policy_loss: 2.8928 - value_loss: 0.1208 - value_mae: 0.2928
# epoch 32
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - loss: 2.9978 - policy_categorical_accuracy: 0.3264 - policy_loss: 2.8770 - value_loss: 0.1207 - value_mae: 0.2933
# epoch 33
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - loss: 2.9886 - policy_categorical_accuracy: 0.3253 - policy_loss: 2.8682 - value_loss: 0.1203 - value_mae: 0.2928
# epoch 34
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - loss: 3.0029 - policy_categorical_accuracy: 0.3194 - policy_loss: 2.8832 - value_loss: 0.1196 - value_mae: 0.2915
# epoch 35
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - loss: 3.0006 - policy_categorical_accuracy: 0.3187 - policy_loss: 2.8800 - value_loss: 0.1205 - value_mae: 0.2927
# epoch 36
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - loss: 2.9615 - policy_categorical_accuracy: 0.3274 - policy_loss: 2.8407 - value_loss: 0.1207 - value_mae: 0.2934
# epoch 37
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - loss: 2.9705 - policy_categorical_accuracy: 0.3251 - policy_loss: 2.8494 - value_loss: 0.1210 - value_mae: 0.2933
# epoch 38
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - loss: 2.9570 - policy_categorical_accuracy: 0.3254 - policy_loss: 2.8358 - value_loss: 0.1210 - value_mae: 0.2944
# epoch 39
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - loss: 2.9702 - policy_categorical_accuracy: 0.3231 - policy_loss: 2.8499 - value_loss: 0.1202 - value_mae: 0.2922
# epoch 40
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - loss: 2.9653 - policy_categorical_accuracy: 0.3263 - policy_loss: 2.8445 - value_loss: 0.1207 - value_mae: 0.2930
# val = [2.9677841663360596, 2.847459554672241, 0.12023498117923737, 0.3265799880027771, 0.29250791668891907]

# %%
model.save('Mellissa_HAFIS-Ilona_LEDROGOFF_ResNet_NoBatch.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
