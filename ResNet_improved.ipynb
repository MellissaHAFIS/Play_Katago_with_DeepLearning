# %% [markdown]
# # The Deep Learning Project
#
# Team members:
# - Mellissa HAFIS
# - Ilona LEDROGOFF

# %%
# !wget https://www.lamsade.dauphine.fr/~cazenave/project2026.zip
# !unzip project2026.zip
# !ls -ly
# Out:
# --2026-01-19 07:09:12--  https://www.lamsade.dauphine.fr/~cazenave/project2026.zip
# Resolving www.lamsade.dauphine.fr (www.lamsade.dauphine.fr)... 193.48.71.250
# Connecting to www.lamsade.dauphine.fr (www.lamsade.dauphine.fr)|193.48.71.250|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 138578548 (132M) [application/zip]
# Saving to: ‘project2026.zip’
#
# project2026.zip     100%[===================>] 132.16M  23.1MB/s    in 7.5s
#
# 2026-01-19 07:09:20 (17.6 MB/s) - ‘project2026.zip’ saved [138578548/138578548]
#
# Archive:  project2026.zip
#   inflating: games.data
#   inflating: golois.cpython-312-x86_64-linux-gnu.so
# ls: invalid option -- 'y'
# Try 'ls --help' for more information.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Version 2

# %%
# !pip install tensorflow

# %%
import tensorflow as tf
import tensorflow.keras as keras
import numpy as np
from tensorflow.keras import layers
from tensorflow.keras import regularizers
import gc

import golois

planes = 31
moves = 361
N = 50000
epochs = 20
batch = 128
filters = 32

input_data = np.random.randint(2, size=(N, 19, 19, planes))
input_data = input_data.astype ('float32')

# %%
policy = np.random.randint(moves, size=(N,))
policy = keras.utils.to_categorical (policy)
policy = policy.astype ('float32')

value = np.random.randint(2, size=(N,))
value = value.astype ('float32')

end = np.random.randint(2, size=(N, 19, 19, 2))
end = end.astype ('float32')

groups = np.zeros((N, 19, 19, 1))
groups = groups.astype ('float32')

print ("Tensorflow version", tf.__version__)
print ("getValidation", flush = True)
golois.getValidation (input_data, policy, value, end)
# Out:
# Tensorflow version 2.19.0
# getValidation

# %%
epochs = 500

# %%
input_data.shape
# Out:
# (50000, 19, 19, 31)

# %% [markdown]
# ## Some improvements:
# - **Version 1:**
# ### In the feature extractor:
# - We change the simple Conv2D into residual blocks
# - It's supposed to help the network to reuse the features efficiently and prevent gradient vanishing problem.
#
# ### Adding a dropout in the value head
# - To prevent overfitting
#
# ### Increasing the number of filters
# - possible values: 35, 40, 45, 48, ...
# - MAX PARMS: 100 000
#
# ### Ajouter une mini-conv avant les têtes
# ---
#
# - **Version 2:**
# - Reduce the number of the parameters
# - Reducing the number of residual blocks (e.g., from 5 to 4).
# - Adding batch normalization to stabilize deeper layers.
#   - After each convolution
#   - Before activation (ReLU)
# - Fine-tuning the dropout rate and L2 regularization for better generalization.

# %%
# Define checkpoint directory (persistent on Drive)
import os
import json
checkpoint_dir = "/content/drive/MyDrive/Master-2-IASD-app/Deep-learning/ResNet/checkpoints"
os.makedirs(checkpoint_dir, exist_ok=True)

checkpoint_path = os.path.join(checkpoint_dir, "model_last.keras")
progress_file = os.path.join(checkpoint_dir, "progress.json")

# %%
progress_file = "/content/drive/MyDrive/Master-2-IASD-app/Deep-learning/ResNet/checkpoints/progress.json"
if os.path.exists(progress_file):
    # !cat {progress_file}
else:
    print(f"File not found: {progress_file}")
# Out:
# {"last_epoch": 765}

# %%
def batchNorm_residual_block(x, filters):
    shortcut = x

    # First conv + BN + ReLU
    x = layers.Conv2D(filters, 3, padding='same', use_bias=False)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)

    # Second conv + BN (no ReLU yet)
    x = layers.Conv2D(filters, 3, padding='same', use_bias=False)(x)
    x = layers.BatchNormalization()(x)

    # Add shortcut connection
    x = layers.Add()([x, shortcut])

    # Final ReLU after addition
    x = layers.Activation('relu')(x)

    return x


# features extractor

input = keras.Input(shape=(19, 19, planes), name='board')

x = layers.Conv2D(filters, 1, padding='same', use_bias=False)(input)
x = layers.BatchNormalization()(x)
x = layers.Activation('relu')(x)

for i in range(4):
    x = batchNorm_residual_block(x, filters)


# policy head
policy_head = layers.Conv2D(2, 1, activation='relu', padding='same')(x)
policy_head = layers.Conv2D(1, 1, activation='relu', padding='same', use_bias = False, kernel_regularizer=regularizers.l2(0.0001))(policy_head)
policy_head = layers.Flatten()(policy_head)
policy_head = layers.Activation('softmax', name='policy')(policy_head)

# value head
value_head = layers.Conv2D(2, 1, activation='relu', padding='same')(x)
value_head = layers.Conv2D(1, 1, activation='relu', padding='same', use_bias = False, kernel_regularizer=regularizers.l2(0.0001))(value_head)
value_head = layers.Flatten()(value_head)
value_head = layers.Dense(50, activation='relu', kernel_regularizer=regularizers.l2(0.001))(value_head)
value_head = layers.Dropout(0.3)(value_head)
value_head = layers.Dense(1, activation='sigmoid', name='value', kernel_regularizer=regularizers.l2(0.0001))(value_head)

model = keras.Model(inputs=input, outputs=[policy_head, value_head])

model.summary ()

# compilation
model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.00099), # init-> 0.0001
              loss={'policy': 'categorical_crossentropy', 'value': 'mse'},
              loss_weights={'policy' : 1.0, 'value' : 1.0},
              metrics={'policy': 'categorical_accuracy', 'value': 'mae'})


# resume if previous checkpoint exists
start_epoch = 0
if os.path.exists(checkpoint_path) and os.path.exists(progress_file):
    print("Loading model from checkpoint...")
    model = keras.models.load_model(checkpoint_path)
    with open(progress_file, "r") as f:
        start_epoch = json.load(f)["last_epoch"]
    print(f"Resuming from epoch {start_epoch + 1}")
else:
    print("Starting training from scratch")

# training
for i in range(start_epoch + 1, start_epoch + epochs + 1):
    print('epoch ' + str (i))
    golois.getBatch (input_data, policy, value, end, groups, i * N)
    history = model.fit(input_data,
                        [policy,value],
                        epochs=1, batch_size=batch)
    # save JSON progress every epoch (lightweight)
    with open(progress_file, "w") as f:
        json.dump({"last_epoch": i}, f)

    if (i % 5 == 0):
        gc.collect ()
    # Save progress every 20 epochs
    if (i % 20 == 0):
        golois.getValidation (input_data, policy, value, end)
        val = model.evaluate (input_data,
                              [policy, value], verbose = 0, batch_size=batch)
        print("val =", val)
        # save model + progress
        model.save(checkpoint_path)
        print(f"Saved checkpoint at epoch {i}")
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ board (InputLayer)  │ (None, 19, 19,    │          0 │ -                 │
# │                     │ 31)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 19, 19,    │        992 │ board[0][0]       │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 19, 19,    │        128 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 19, 19,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 19, 19,    │      9,216 │ activation[0][0]  │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 19, 19,    │        128 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 19, 19,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 19, 19,    │      9,216 │ activation_1[0][… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 19, 19,    │        128 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 19, 19,    │          0 │ batch_normalizat… │
# │                     │ 32)               │            │ activation[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 19, 19,    │          0 │ add[0][0]         │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 19, 19,    │      9,216 │ activation_2[0][… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 19, 19,    │        128 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 19, 19,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 19, 19,    │      9,216 │ activation_3[0][… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 19, 19,    │        128 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 19, 19,    │          0 │ batch_normalizat… │
# │                     │ 32)               │            │ activation_2[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 19, 19,    │          0 │ add_1[0][0]       │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 19, 19,    │      9,216 │ activation_4[0][… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 19, 19,    │        128 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 19, 19,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 19, 19,    │      9,216 │ activation_5[0][… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 19, 19,    │        128 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 19, 19,    │          0 │ batch_normalizat… │
# │                     │ 32)               │            │ activation_4[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 19, 19,    │          0 │ add_2[0][0]       │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 19, 19,    │      9,216 │ activation_6[0][… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 19, 19,    │        128 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 19, 19,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 19, 19,    │      9,216 │ activation_7[0][… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 19, 19,    │        128 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 19, 19,    │          0 │ batch_normalizat… │
# │                     │ 32)               │            │ activation_6[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (None, 19, 19,    │          0 │ add_3[0][0]       │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 19, 19, 2) │         66 │ activation_8[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 19, 19, 1) │          2 │ conv2d_11[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 19, 19, 2) │         66 │ activation_8[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_1 (Flatten) │ (None, 361)       │          0 │ conv2d_12[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 19, 19, 1) │          2 │ conv2d_9[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 50)        │     18,100 │ flatten_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 361)       │          0 │ conv2d_10[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 50)        │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ policy (Activation) │ (None, 361)       │          0 │ flatten[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ value (Dense)       │ (None, 1)         │         51 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 94,159 (367.81 KB)
#  Trainable params: 93,583 (365.56 KB)
#  Non-trainable params: 576 (2.25 KB)
# Loading model from checkpoint...
# Resuming from epoch 506
# epoch 506
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 20s 35ms/step - loss: 2.4326 - policy_categorical_accuracy: 0.4032 - policy_loss: 2.3125 - value_loss: 0.1201 - value_mae: 0.2926
# epoch 507
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - loss: 2.4163 - policy_categorical_accuracy: 0.4068 - policy_loss: 2.2963 - value_loss: 0.1200 - value_mae: 0.2922
# epoch 508
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - loss: 2.4257 - policy_categorical_accuracy: 0.4020 - policy_loss: 2.3046 - value_loss: 0.1211 - value_mae: 0.2941
# epoch 509
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 13s 34ms/step - loss: 2.4064 - policy_categorical_accuracy: 0.4065 - policy_loss: 2.2870 - value_loss: 0.1194 - value_mae: 0.2913
# epoch 510
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 13s 34ms/step - loss: 2.4278 - policy_categorical_accuracy: 0.4057 - policy_loss: 2.3070 - value_loss: 0.1208 - value_mae: 0.2936
# epoch 511
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 13s 34ms/step - loss: 2.4176 - policy_categorical_accuracy: 0.4093 - policy_loss: 2.2971 - value_loss: 0.1205 - value_mae: 0.2932
# epoch 512
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - loss: 2.4274 - policy_categorical_accuracy: 0.4045 - policy_loss: 2.3083 - value_loss: 0.1191 - value_mae: 0.2902
# epoch 513
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 13s 34ms/step - loss: 2.4150 - policy_categorical_accuracy: 0.4056 - policy_loss: 2.2951 - value_loss: 0.1198 - value_mae: 0.2921
# epoch 514
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 13s 34ms/step - loss: 2.4280 - policy_categorical_accuracy: 0.4002 - policy_loss: 2.3074 - value_loss: 0.1206 - value_mae: 0.2929
# epoch 515
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 34ms/step - loss: 2.4225 - policy_categorical_accuracy: 0.4033 - policy_loss: 2.3025 - value_loss: 0.1200 - value_mae: 0.2923
# epoch 516
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 13s 34ms/step - loss: 2.4348 - policy_categorical_accuracy: 0.3977 - policy_loss: 2.3148 - value_loss: 0.1200 - value_mae: 0.2924
# epoch 517
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - loss: 2.4258 - policy_categorical_accuracy: 0.4027 - policy_loss: 2.3049 - value_loss: 0.1209 - value_mae: 0.2940
# epoch 518
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - loss: 2.4138 - policy_categorical_accuracy: 0.4089 - policy_loss: 2.2929 - value_loss: 0.1209 - value_mae: 0.2941
# epoch 519
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - loss: 2.4227 - policy_categorical_accuracy: 0.4078 - policy_loss: 2.3025 - value_loss: 0.1202 - value_mae: 0.2928
# epoch 520
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - loss: 2.4335 - policy_categorical_accuracy: 0.3999 - policy_loss: 2.3127 - value_loss: 0.1208 - value_mae: 0.2935
# val = [2.438472032546997, 2.3182597160339355, 0.12023499608039856, 0.40345999598503113, 0.29250776767730713]
# Saved checkpoint at epoch 520
# epoch 521
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - loss: 2.4282 - policy_categorical_accuracy: 0.4020 - policy_loss: 2.3079 - value_loss: 0.1203 - value_mae: 0.2928
# epoch 522
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4217 - policy_categorical_accuracy: 0.4061 - policy_loss: 2.3024 - value_loss: 0.1194 - value_mae: 0.2911
# epoch 523
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - loss: 2.4038 - policy_categorical_accuracy: 0.4108 - policy_loss: 2.2842 - value_loss: 0.1196 - value_mae: 0.2916
# epoch 524
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4224 - policy_categorical_accuracy: 0.4058 - policy_loss: 2.3022 - value_loss: 0.1202 - value_mae: 0.2925
# epoch 525
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4072 - policy_categorical_accuracy: 0.4072 - policy_loss: 2.2866 - value_loss: 0.1206 - value_mae: 0.2936
# epoch 526
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - loss: 2.4234 - policy_categorical_accuracy: 0.4034 - policy_loss: 2.3032 - value_loss: 0.1202 - value_mae: 0.2927
# epoch 527
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - loss: 2.3993 - policy_categorical_accuracy: 0.4104 - policy_loss: 2.2785 - value_loss: 0.1208 - value_mae: 0.2931
# epoch 528
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - loss: 2.4222 - policy_categorical_accuracy: 0.4051 - policy_loss: 2.3031 - value_loss: 0.1191 - value_mae: 0.2908
# epoch 529
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - loss: 2.4168 - policy_categorical_accuracy: 0.4075 - policy_loss: 2.2970 - value_loss: 0.1199 - value_mae: 0.2917
# epoch 530
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - loss: 2.4370 - policy_categorical_accuracy: 0.4014 - policy_loss: 2.3168 - value_loss: 0.1202 - value_mae: 0.2923
# epoch 531
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - loss: 2.4239 - policy_categorical_accuracy: 0.4002 - policy_loss: 2.3016 - value_loss: 0.1223 - value_mae: 0.2961
# epoch 532
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 15s 37ms/step - loss: 2.4388 - policy_categorical_accuracy: 0.4032 - policy_loss: 2.3183 - value_loss: 0.1206 - value_mae: 0.2933
# epoch 533
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 37ms/step - loss: 2.4239 - policy_categorical_accuracy: 0.4041 - policy_loss: 2.3036 - value_loss: 0.1203 - value_mae: 0.2929
# epoch 534
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 37ms/step - loss: 2.4286 - policy_categorical_accuracy: 0.4012 - policy_loss: 2.3080 - value_loss: 0.1205 - value_mae: 0.2932
# epoch 535
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - loss: 2.4243 - policy_categorical_accuracy: 0.4068 - policy_loss: 2.3040 - value_loss: 0.1203 - value_mae: 0.2932
# epoch 536
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - loss: 2.4267 - policy_categorical_accuracy: 0.4032 - policy_loss: 2.3065 - value_loss: 0.1202 - value_mae: 0.2924
# epoch 537
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4182 - policy_categorical_accuracy: 0.4093 - policy_loss: 2.2973 - value_loss: 0.1208 - value_mae: 0.2940
# epoch 538
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4224 - policy_categorical_accuracy: 0.4018 - policy_loss: 2.3016 - value_loss: 0.1207 - value_mae: 0.2932
# epoch 539
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - loss: 2.4102 - policy_categorical_accuracy: 0.4086 - policy_loss: 2.2888 - value_loss: 0.1213 - value_mae: 0.2949
# epoch 540
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4203 - policy_categorical_accuracy: 0.4042 - policy_loss: 2.3002 - value_loss: 0.1201 - value_mae: 0.2923
# val = [2.4382171630859375, 2.318016529083252, 0.12024436891078949, 0.4046599864959717, 0.2925556004047394]
# Saved checkpoint at epoch 540
# epoch 541
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4172 - policy_categorical_accuracy: 0.4020 - policy_loss: 2.2964 - value_loss: 0.1209 - value_mae: 0.2941
# epoch 542
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 37ms/step - loss: 2.4039 - policy_categorical_accuracy: 0.4093 - policy_loss: 2.2855 - value_loss: 0.1184 - value_mae: 0.2893
# epoch 543
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4053 - policy_categorical_accuracy: 0.4081 - policy_loss: 2.2838 - value_loss: 0.1215 - value_mae: 0.2950
# epoch 544
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4109 - policy_categorical_accuracy: 0.4060 - policy_loss: 2.2900 - value_loss: 0.1209 - value_mae: 0.2938
# epoch 545
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4104 - policy_categorical_accuracy: 0.4054 - policy_loss: 2.2897 - value_loss: 0.1207 - value_mae: 0.2934
# epoch 546
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 37ms/step - loss: 2.4113 - policy_categorical_accuracy: 0.4052 - policy_loss: 2.2907 - value_loss: 0.1205 - value_mae: 0.2931
# epoch 547
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 37ms/step - loss: 2.4280 - policy_categorical_accuracy: 0.4037 - policy_loss: 2.3070 - value_loss: 0.1210 - value_mae: 0.2937
# epoch 548
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 37ms/step - loss: 2.4043 - policy_categorical_accuracy: 0.4043 - policy_loss: 2.2843 - value_loss: 0.1199 - value_mae: 0.2916
# epoch 549
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 37ms/step - loss: 2.4065 - policy_categorical_accuracy: 0.4072 - policy_loss: 2.2871 - value_loss: 0.1194 - value_mae: 0.2910
# epoch 550
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 37ms/step - loss: 2.4408 - policy_categorical_accuracy: 0.4015 - policy_loss: 2.3201 - value_loss: 0.1206 - value_mae: 0.2934
# epoch 551
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 37ms/step - loss: 2.4252 - policy_categorical_accuracy: 0.4055 - policy_loss: 2.3052 - value_loss: 0.1200 - value_mae: 0.2925
# epoch 552
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4242 - policy_categorical_accuracy: 0.4010 - policy_loss: 2.3030 - value_loss: 0.1212 - value_mae: 0.2941
# epoch 553
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 37ms/step - loss: 2.4268 - policy_categorical_accuracy: 0.4036 - policy_loss: 2.3071 - value_loss: 0.1197 - value_mae: 0.2915
# epoch 554
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4131 - policy_categorical_accuracy: 0.4074 - policy_loss: 2.2915 - value_loss: 0.1216 - value_mae: 0.2949
# epoch 555
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - loss: 2.4382 - policy_categorical_accuracy: 0.4017 - policy_loss: 2.3176 - value_loss: 0.1205 - value_mae: 0.2931
# epoch 556
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - loss: 2.4042 - policy_categorical_accuracy: 0.4063 - policy_loss: 2.2829 - value_loss: 0.1212 - value_mae: 0.2941
# epoch 557
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - loss: 2.4336 - policy_categorical_accuracy: 0.4011 - policy_loss: 2.3119 - value_loss: 0.1217 - value_mae: 0.2953
# epoch 558
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - loss: 2.4147 - policy_categorical_accuracy: 0.4077 - policy_loss: 2.2946 - value_loss: 0.1201 - value_mae: 0.2922
# epoch 559
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - loss: 2.4309 - policy_categorical_accuracy: 0.4011 - policy_loss: 2.3097 - value_loss: 0.1212 - value_mae: 0.2942
# epoch 560
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - loss: 2.4271 - policy_categorical_accuracy: 0.4069 - policy_loss: 2.3065 - value_loss: 0.1206 - value_mae: 0.2934
# val = [2.433934450149536, 2.313666582107544, 0.12023387849330902, 0.405239999294281, 0.2925293743610382]
# Saved checkpoint at epoch 560
# epoch 561
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - loss: 2.4379 - policy_categorical_accuracy: 0.4037 - policy_loss: 2.3179 - value_loss: 0.1201 - value_mae: 0.2926
# epoch 562
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - loss: 2.4163 - policy_categorical_accuracy: 0.4032 - policy_loss: 2.2964 - value_loss: 0.1199 - value_mae: 0.2921
# epoch 563
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4400 - policy_categorical_accuracy: 0.4026 - policy_loss: 2.3201 - value_loss: 0.1199 - value_mae: 0.2920
# epoch 564
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - loss: 2.4242 - policy_categorical_accuracy: 0.4039 - policy_loss: 2.3029 - value_loss: 0.1212 - value_mae: 0.2943
# epoch 565
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - loss: 2.4378 - policy_categorical_accuracy: 0.3995 - policy_loss: 2.3169 - value_loss: 0.1209 - value_mae: 0.2941
# epoch 566
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - loss: 2.4299 - policy_categorical_accuracy: 0.4040 - policy_loss: 2.3080 - value_loss: 0.1219 - value_mae: 0.2954
# epoch 567
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - loss: 2.4265 - policy_categorical_accuracy: 0.4038 - policy_loss: 2.3060 - value_loss: 0.1205 - value_mae: 0.2935
# epoch 568
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 15s 38ms/step - loss: 2.4154 - policy_categorical_accuracy: 0.4060 - policy_loss: 2.2938 - value_loss: 0.1216 - value_mae: 0.2951
# epoch 569
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - loss: 2.4142 - policy_categorical_accuracy: 0.4057 - policy_loss: 2.2932 - value_loss: 0.1209 - value_mae: 0.2938
# epoch 570
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - loss: 2.4209 - policy_categorical_accuracy: 0.4053 - policy_loss: 2.3011 - value_loss: 0.1198 - value_mae: 0.2921
# epoch 571
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - loss: 2.4242 - policy_categorical_accuracy: 0.4051 - policy_loss: 2.3050 - value_loss: 0.1192 - value_mae: 0.2906
# epoch 572
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4230 - policy_categorical_accuracy: 0.4036 - policy_loss: 2.3019 - value_loss: 0.1211 - value_mae: 0.2942
# epoch 573
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - loss: 2.4098 - policy_categorical_accuracy: 0.4072 - policy_loss: 2.2895 - value_loss: 0.1203 - value_mae: 0.2927
# epoch 574
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - loss: 2.4125 - policy_categorical_accuracy: 0.4030 - policy_loss: 2.2923 - value_loss: 0.1202 - value_mae: 0.2927
# epoch 575
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - loss: 2.4193 - policy_categorical_accuracy: 0.4085 - policy_loss: 2.2983 - value_loss: 0.1209 - value_mae: 0.2939
# epoch 576
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - loss: 2.4338 - policy_categorical_accuracy: 0.4018 - policy_loss: 2.3134 - value_loss: 0.1204 - value_mae: 0.2930
# epoch 577
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4070 - policy_categorical_accuracy: 0.4095 - policy_loss: 2.2874 - value_loss: 0.1196 - value_mae: 0.2916
# epoch 578
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4184 - policy_categorical_accuracy: 0.4017 - policy_loss: 2.2985 - value_loss: 0.1199 - value_mae: 0.2919
# epoch 579
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - loss: 2.4274 - policy_categorical_accuracy: 0.4038 - policy_loss: 2.3069 - value_loss: 0.1205 - value_mae: 0.2930
# epoch 580
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4265 - policy_categorical_accuracy: 0.4043 - policy_loss: 2.3053 - value_loss: 0.1212 - value_mae: 0.2944
# val = [2.4352598190307617, 2.315086841583252, 0.12023459374904633, 0.4044800102710724, 0.2925083339214325]
# Saved checkpoint at epoch 580
# epoch 581
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4108 - policy_categorical_accuracy: 0.4085 - policy_loss: 2.2912 - value_loss: 0.1196 - value_mae: 0.2915
# epoch 582
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - loss: 2.4242 - policy_categorical_accuracy: 0.4042 - policy_loss: 2.3040 - value_loss: 0.1201 - value_mae: 0.2921
# epoch 583
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - loss: 2.4083 - policy_categorical_accuracy: 0.4069 - policy_loss: 2.2875 - value_loss: 0.1209 - value_mae: 0.2941
# epoch 584
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - loss: 2.4349 - policy_categorical_accuracy: 0.4021 - policy_loss: 2.3149 - value_loss: 0.1201 - value_mae: 0.2925
# epoch 585
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - loss: 2.4197 - policy_categorical_accuracy: 0.4077 - policy_loss: 2.2995 - value_loss: 0.1202 - value_mae: 0.2924
# epoch 586
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - loss: 2.4167 - policy_categorical_accuracy: 0.4054 - policy_loss: 2.2955 - value_loss: 0.1212 - value_mae: 0.2942
# epoch 587
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4056 - policy_categorical_accuracy: 0.4100 - policy_loss: 2.2854 - value_loss: 0.1201 - value_mae: 0.2929
# epoch 588
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - loss: 2.4212 - policy_categorical_accuracy: 0.4007 - policy_loss: 2.3012 - value_loss: 0.1200 - value_mae: 0.2920
# epoch 589
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - loss: 2.4257 - policy_categorical_accuracy: 0.4025 - policy_loss: 2.3045 - value_loss: 0.1212 - value_mae: 0.2946
# epoch 590
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - loss: 2.4337 - policy_categorical_accuracy: 0.4023 - policy_loss: 2.3135 - value_loss: 0.1202 - value_mae: 0.2927
# epoch 591
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4303 - policy_categorical_accuracy: 0.4047 - policy_loss: 2.3108 - value_loss: 0.1195 - value_mae: 0.2914
# epoch 592
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - loss: 2.4276 - policy_categorical_accuracy: 0.4010 - policy_loss: 2.3081 - value_loss: 0.1195 - value_mae: 0.2915
# epoch 593
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - loss: 2.4165 - policy_categorical_accuracy: 0.4039 - policy_loss: 2.2960 - value_loss: 0.1205 - value_mae: 0.2930
# epoch 594
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - loss: 2.4104 - policy_categorical_accuracy: 0.4089 - policy_loss: 2.2892 - value_loss: 0.1212 - value_mae: 0.2941
# epoch 595
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4229 - policy_categorical_accuracy: 0.4039 - policy_loss: 2.3038 - value_loss: 0.1190 - value_mae: 0.2901
# epoch 596
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4324 - policy_categorical_accuracy: 0.4054 - policy_loss: 2.3123 - value_loss: 0.1201 - value_mae: 0.2927
# epoch 597
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.3996 - policy_categorical_accuracy: 0.4086 - policy_loss: 2.2793 - value_loss: 0.1203 - value_mae: 0.2926
# epoch 598
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4255 - policy_categorical_accuracy: 0.4039 - policy_loss: 2.3055 - value_loss: 0.1200 - value_mae: 0.2922
# epoch 599
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4062 - policy_categorical_accuracy: 0.4070 - policy_loss: 2.2866 - value_loss: 0.1196 - value_mae: 0.2911
# epoch 600
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4178 - policy_categorical_accuracy: 0.4041 - policy_loss: 2.2977 - value_loss: 0.1201 - value_mae: 0.2926
# val = [2.4337258338928223, 2.3134713172912598, 0.12024436146020889, 0.40303999185562134, 0.2925376892089844]
# Saved checkpoint at epoch 600
# epoch 601
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.3937 - policy_categorical_accuracy: 0.4109 - policy_loss: 2.2730 - value_loss: 0.1207 - value_mae: 0.2932
# epoch 602
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4136 - policy_categorical_accuracy: 0.4075 - policy_loss: 2.2926 - value_loss: 0.1210 - value_mae: 0.2941
# epoch 603
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4261 - policy_categorical_accuracy: 0.4058 - policy_loss: 2.3043 - value_loss: 0.1219 - value_mae: 0.2953
# epoch 604
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4202 - policy_categorical_accuracy: 0.4046 - policy_loss: 2.2993 - value_loss: 0.1210 - value_mae: 0.2935
# epoch 605
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4091 - policy_categorical_accuracy: 0.4021 - policy_loss: 2.2884 - value_loss: 0.1207 - value_mae: 0.2934
# epoch 606
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.3939 - policy_categorical_accuracy: 0.4079 - policy_loss: 2.2729 - value_loss: 0.1210 - value_mae: 0.2938
# epoch 607
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4034 - policy_categorical_accuracy: 0.4072 - policy_loss: 2.2833 - value_loss: 0.1201 - value_mae: 0.2924
# epoch 608
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4067 - policy_categorical_accuracy: 0.4078 - policy_loss: 2.2856 - value_loss: 0.1211 - value_mae: 0.2940
# epoch 609
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4314 - policy_categorical_accuracy: 0.4001 - policy_loss: 2.3109 - value_loss: 0.1206 - value_mae: 0.2933
# epoch 610
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4237 - policy_categorical_accuracy: 0.4073 - policy_loss: 2.3037 - value_loss: 0.1200 - value_mae: 0.2924
# epoch 611
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4224 - policy_categorical_accuracy: 0.4057 - policy_loss: 2.3020 - value_loss: 0.1205 - value_mae: 0.2931
# epoch 612
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4238 - policy_categorical_accuracy: 0.4058 - policy_loss: 2.3040 - value_loss: 0.1198 - value_mae: 0.2922
# epoch 613
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4218 - policy_categorical_accuracy: 0.4059 - policy_loss: 2.3015 - value_loss: 0.1203 - value_mae: 0.2930
# epoch 614
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4355 - policy_categorical_accuracy: 0.4046 - policy_loss: 2.3153 - value_loss: 0.1203 - value_mae: 0.2925
# epoch 615
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4249 - policy_categorical_accuracy: 0.4034 - policy_loss: 2.3056 - value_loss: 0.1193 - value_mae: 0.2912
# epoch 616
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4071 - policy_categorical_accuracy: 0.4090 - policy_loss: 2.2874 - value_loss: 0.1196 - value_mae: 0.2919
# epoch 617
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4131 - policy_categorical_accuracy: 0.4060 - policy_loss: 2.2916 - value_loss: 0.1214 - value_mae: 0.2945
# epoch 618
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4223 - policy_categorical_accuracy: 0.4072 - policy_loss: 2.3010 - value_loss: 0.1213 - value_mae: 0.2944
# epoch 619
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4136 - policy_categorical_accuracy: 0.4044 - policy_loss: 2.2931 - value_loss: 0.1205 - value_mae: 0.2932
# epoch 620
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4171 - policy_categorical_accuracy: 0.4024 - policy_loss: 2.2979 - value_loss: 0.1192 - value_mae: 0.2908
# val = [2.4322550296783447, 2.3120310306549072, 0.12023569643497467, 0.4032599925994873, 0.29251131415367126]
# Saved checkpoint at epoch 620
# epoch 621
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4193 - policy_categorical_accuracy: 0.4039 - policy_loss: 2.2987 - value_loss: 0.1205 - value_mae: 0.2931
# epoch 622
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4113 - policy_categorical_accuracy: 0.4043 - policy_loss: 2.2910 - value_loss: 0.1202 - value_mae: 0.2926
# epoch 623
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4395 - policy_categorical_accuracy: 0.4040 - policy_loss: 2.3182 - value_loss: 0.1213 - value_mae: 0.2945
# epoch 624
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4088 - policy_categorical_accuracy: 0.4128 - policy_loss: 2.2885 - value_loss: 0.1204 - value_mae: 0.2928
# epoch 625
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4202 - policy_categorical_accuracy: 0.4043 - policy_loss: 2.3007 - value_loss: 0.1195 - value_mae: 0.2915
# epoch 626
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4114 - policy_categorical_accuracy: 0.4105 - policy_loss: 2.2915 - value_loss: 0.1200 - value_mae: 0.2918
# epoch 627
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4093 - policy_categorical_accuracy: 0.4064 - policy_loss: 2.2893 - value_loss: 0.1200 - value_mae: 0.2920
# epoch 628
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4243 - policy_categorical_accuracy: 0.4046 - policy_loss: 2.3032 - value_loss: 0.1212 - value_mae: 0.2944
# epoch 629
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4219 - policy_categorical_accuracy: 0.4010 - policy_loss: 2.3013 - value_loss: 0.1205 - value_mae: 0.2936
# epoch 630
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4310 - policy_categorical_accuracy: 0.3981 - policy_loss: 2.3107 - value_loss: 0.1203 - value_mae: 0.2930
# epoch 631
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4195 - policy_categorical_accuracy: 0.4048 - policy_loss: 2.2986 - value_loss: 0.1209 - value_mae: 0.2935
# epoch 632
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4281 - policy_categorical_accuracy: 0.4006 - policy_loss: 2.3082 - value_loss: 0.1199 - value_mae: 0.2919
# epoch 633
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4117 - policy_categorical_accuracy: 0.4061 - policy_loss: 2.2915 - value_loss: 0.1202 - value_mae: 0.2925
# epoch 634
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4167 - policy_categorical_accuracy: 0.4058 - policy_loss: 2.2963 - value_loss: 0.1204 - value_mae: 0.2925
# epoch 635
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 37ms/step - loss: 2.4326 - policy_categorical_accuracy: 0.4030 - policy_loss: 2.3112 - value_loss: 0.1214 - value_mae: 0.2948
# epoch 636
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4170 - policy_categorical_accuracy: 0.4061 - policy_loss: 2.2966 - value_loss: 0.1204 - value_mae: 0.2927
# epoch 637
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4380 - policy_categorical_accuracy: 0.3998 - policy_loss: 2.3170 - value_loss: 0.1210 - value_mae: 0.2938
# epoch 638
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 37ms/step - loss: 2.4036 - policy_categorical_accuracy: 0.4089 - policy_loss: 2.2837 - value_loss: 0.1200 - value_mae: 0.2919
# epoch 639
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4364 - policy_categorical_accuracy: 0.4009 - policy_loss: 2.3161 - value_loss: 0.1203 - value_mae: 0.2927
# epoch 640
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4217 - policy_categorical_accuracy: 0.4079 - policy_loss: 2.3017 - value_loss: 0.1200 - value_mae: 0.2924
# val = [2.429220676422119, 2.3090097904205322, 0.12023370712995529, 0.4042600095272064, 0.2925277352333069]
# Saved checkpoint at epoch 640
# epoch 641
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - loss: 2.4201 - policy_categorical_accuracy: 0.4049 - policy_loss: 2.2986 - value_loss: 0.1215 - value_mae: 0.2945
# epoch 642
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4236 - policy_categorical_accuracy: 0.4041 - policy_loss: 2.3042 - value_loss: 0.1194 - value_mae: 0.2909
# epoch 643
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4429 - policy_categorical_accuracy: 0.4011 - policy_loss: 2.3224 - value_loss: 0.1204 - value_mae: 0.2933
# epoch 644
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4252 - policy_categorical_accuracy: 0.4077 - policy_loss: 2.3036 - value_loss: 0.1216 - value_mae: 0.2949
# epoch 645
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4219 - policy_categorical_accuracy: 0.4045 - policy_loss: 2.3015 - value_loss: 0.1204 - value_mae: 0.2929
# epoch 646
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4053 - policy_categorical_accuracy: 0.4065 - policy_loss: 2.2856 - value_loss: 0.1197 - value_mae: 0.2920
# epoch 647
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.3978 - policy_categorical_accuracy: 0.4067 - policy_loss: 2.2771 - value_loss: 0.1207 - value_mae: 0.2934
# epoch 648
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4264 - policy_categorical_accuracy: 0.4054 - policy_loss: 2.3069 - value_loss: 0.1195 - value_mae: 0.2910
# epoch 649
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4078 - policy_categorical_accuracy: 0.4067 - policy_loss: 2.2883 - value_loss: 0.1195 - value_mae: 0.2915
# epoch 650
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - loss: 2.4337 - policy_categorical_accuracy: 0.3984 - policy_loss: 2.3137 - value_loss: 0.1199 - value_mae: 0.2921
# epoch 651
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - loss: 2.4072 - policy_categorical_accuracy: 0.4089 - policy_loss: 2.2863 - value_loss: 0.1209 - value_mae: 0.2941
# epoch 652
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4174 - policy_categorical_accuracy: 0.4077 - policy_loss: 2.2994 - value_loss: 0.1180 - value_mae: 0.2891
# epoch 653
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - loss: 2.4222 - policy_categorical_accuracy: 0.4054 - policy_loss: 2.3033 - value_loss: 0.1189 - value_mae: 0.2908
# epoch 654
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.3935 - policy_categorical_accuracy: 0.4064 - policy_loss: 2.2730 - value_loss: 0.1205 - value_mae: 0.2931
# epoch 655
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4139 - policy_categorical_accuracy: 0.4085 - policy_loss: 2.2940 - value_loss: 0.1199 - value_mae: 0.2920
# epoch 656
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - loss: 2.4294 - policy_categorical_accuracy: 0.4004 - policy_loss: 2.3087 - value_loss: 0.1208 - value_mae: 0.2933
# epoch 657
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4285 - policy_categorical_accuracy: 0.4024 - policy_loss: 2.3082 - value_loss: 0.1203 - value_mae: 0.2929
# epoch 658
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - loss: 2.4087 - policy_categorical_accuracy: 0.4067 - policy_loss: 2.2885 - value_loss: 0.1202 - value_mae: 0.2923
# epoch 659
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.3893 - policy_categorical_accuracy: 0.4091 - policy_loss: 2.2688 - value_loss: 0.1205 - value_mae: 0.2933
# epoch 660
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - loss: 2.4162 - policy_categorical_accuracy: 0.4056 - policy_loss: 2.2955 - value_loss: 0.1207 - value_mae: 0.2936
# val = [2.432229518890381, 2.3119966983795166, 0.1202368512749672, 0.40478000044822693, 0.29251644015312195]
# Saved checkpoint at epoch 660
# epoch 661
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - loss: 2.4236 - policy_categorical_accuracy: 0.4043 - policy_loss: 2.3039 - value_loss: 0.1197 - value_mae: 0.2916
# epoch 662
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4015 - policy_categorical_accuracy: 0.4060 - policy_loss: 2.2816 - value_loss: 0.1199 - value_mae: 0.2921
# epoch 663
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4270 - policy_categorical_accuracy: 0.4004 - policy_loss: 2.3062 - value_loss: 0.1208 - value_mae: 0.2940
# epoch 664
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - loss: 2.4028 - policy_categorical_accuracy: 0.4077 - policy_loss: 2.2832 - value_loss: 0.1195 - value_mae: 0.2916
# epoch 665
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4238 - policy_categorical_accuracy: 0.4020 - policy_loss: 2.3027 - value_loss: 0.1211 - value_mae: 0.2940
# epoch 666
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4123 - policy_categorical_accuracy: 0.4071 - policy_loss: 2.2917 - value_loss: 0.1206 - value_mae: 0.2930
# epoch 667
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.3902 - policy_categorical_accuracy: 0.4128 - policy_loss: 2.2705 - value_loss: 0.1197 - value_mae: 0.2917
# epoch 668
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4109 - policy_categorical_accuracy: 0.4061 - policy_loss: 2.2900 - value_loss: 0.1209 - value_mae: 0.2935
# epoch 669
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - loss: 2.4014 - policy_categorical_accuracy: 0.4067 - policy_loss: 2.2828 - value_loss: 0.1186 - value_mae: 0.2902
# epoch 670
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4198 - policy_categorical_accuracy: 0.4017 - policy_loss: 2.3005 - value_loss: 0.1193 - value_mae: 0.2912
# epoch 671
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - loss: 2.4359 - policy_categorical_accuracy: 0.4021 - policy_loss: 2.3161 - value_loss: 0.1198 - value_mae: 0.2922
# epoch 672
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4019 - policy_categorical_accuracy: 0.4062 - policy_loss: 2.2815 - value_loss: 0.1204 - value_mae: 0.2925
# epoch 673
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4002 - policy_categorical_accuracy: 0.4089 - policy_loss: 2.2784 - value_loss: 0.1218 - value_mae: 0.2953
# epoch 674
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4234 - policy_categorical_accuracy: 0.4002 - policy_loss: 2.3016 - value_loss: 0.1218 - value_mae: 0.2953
# epoch 675
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - loss: 2.4247 - policy_categorical_accuracy: 0.4068 - policy_loss: 2.3038 - value_loss: 0.1210 - value_mae: 0.2939
# epoch 676
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4138 - policy_categorical_accuracy: 0.4056 - policy_loss: 2.2942 - value_loss: 0.1197 - value_mae: 0.2921
# epoch 677
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4284 - policy_categorical_accuracy: 0.4049 - policy_loss: 2.3073 - value_loss: 0.1211 - value_mae: 0.2943
# epoch 678
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - loss: 2.3991 - policy_categorical_accuracy: 0.4076 - policy_loss: 2.2781 - value_loss: 0.1210 - value_mae: 0.2941
# epoch 679
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4100 - policy_categorical_accuracy: 0.4068 - policy_loss: 2.2904 - value_loss: 0.1196 - value_mae: 0.2914
# epoch 680
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4124 - policy_categorical_accuracy: 0.4013 - policy_loss: 2.2920 - value_loss: 0.1204 - value_mae: 0.2930
# val = [2.4379899501800537, 2.31775164604187, 0.12023387104272842, 0.4048199951648712, 0.292511910200119]
# Saved checkpoint at epoch 680
# epoch 681
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - loss: 2.3930 - policy_categorical_accuracy: 0.4132 - policy_loss: 2.2728 - value_loss: 0.1202 - value_mae: 0.2928
# epoch 682
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4150 - policy_categorical_accuracy: 0.4080 - policy_loss: 2.2932 - value_loss: 0.1217 - value_mae: 0.2957
# epoch 683
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - loss: 2.3979 - policy_categorical_accuracy: 0.4075 - policy_loss: 2.2770 - value_loss: 0.1210 - value_mae: 0.2940
# epoch 684
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - loss: 2.4201 - policy_categorical_accuracy: 0.4016 - policy_loss: 2.3003 - value_loss: 0.1197 - value_mae: 0.2920
# epoch 685
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4131 - policy_categorical_accuracy: 0.4073 - policy_loss: 2.2916 - value_loss: 0.1215 - value_mae: 0.2952
# epoch 686
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4049 - policy_categorical_accuracy: 0.4083 - policy_loss: 2.2843 - value_loss: 0.1206 - value_mae: 0.2927
# epoch 687
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4174 - policy_categorical_accuracy: 0.4012 - policy_loss: 2.2968 - value_loss: 0.1207 - value_mae: 0.2930
# epoch 688
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4223 - policy_categorical_accuracy: 0.4060 - policy_loss: 2.3014 - value_loss: 0.1208 - value_mae: 0.2937
# epoch 689
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4219 - policy_categorical_accuracy: 0.4051 - policy_loss: 2.3016 - value_loss: 0.1204 - value_mae: 0.2934
# epoch 690
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4088 - policy_categorical_accuracy: 0.4056 - policy_loss: 2.2868 - value_loss: 0.1220 - value_mae: 0.2954
# epoch 691
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4226 - policy_categorical_accuracy: 0.4017 - policy_loss: 2.3022 - value_loss: 0.1204 - value_mae: 0.2929
# epoch 692
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.3901 - policy_categorical_accuracy: 0.4100 - policy_loss: 2.2695 - value_loss: 0.1206 - value_mae: 0.2931
# epoch 693
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4107 - policy_categorical_accuracy: 0.4054 - policy_loss: 2.2905 - value_loss: 0.1202 - value_mae: 0.2925
# epoch 694
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4051 - policy_categorical_accuracy: 0.4061 - policy_loss: 2.2850 - value_loss: 0.1201 - value_mae: 0.2922
# epoch 695
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4030 - policy_categorical_accuracy: 0.4014 - policy_loss: 2.2820 - value_loss: 0.1210 - value_mae: 0.2939
# epoch 696
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4209 - policy_categorical_accuracy: 0.4048 - policy_loss: 2.3000 - value_loss: 0.1209 - value_mae: 0.2938
# epoch 697
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4275 - policy_categorical_accuracy: 0.4052 - policy_loss: 2.3062 - value_loss: 0.1213 - value_mae: 0.2943
# epoch 698
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 37ms/step - loss: 2.4227 - policy_categorical_accuracy: 0.4049 - policy_loss: 2.3018 - value_loss: 0.1209 - value_mae: 0.2937
# epoch 699
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 15s 38ms/step - loss: 2.3960 - policy_categorical_accuracy: 0.4115 - policy_loss: 2.2766 - value_loss: 0.1194 - value_mae: 0.2910
# epoch 700
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4118 - policy_categorical_accuracy: 0.4056 - policy_loss: 2.2907 - value_loss: 0.1211 - value_mae: 0.2943
# val = [2.421626329421997, 2.301339626312256, 0.12023693323135376, 0.4053399860858917, 0.2925170063972473]
# Saved checkpoint at epoch 700
# epoch 701
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 15s 39ms/step - loss: 2.4202 - policy_categorical_accuracy: 0.4039 - policy_loss: 2.2997 - value_loss: 0.1205 - value_mae: 0.2930
# epoch 702
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 37ms/step - loss: 2.4177 - policy_categorical_accuracy: 0.4054 - policy_loss: 2.2972 - value_loss: 0.1205 - value_mae: 0.2929
# epoch 703
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.3956 - policy_categorical_accuracy: 0.4044 - policy_loss: 2.2756 - value_loss: 0.1200 - value_mae: 0.2920
# epoch 704
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - loss: 2.4157 - policy_categorical_accuracy: 0.4077 - policy_loss: 2.2955 - value_loss: 0.1202 - value_mae: 0.2926
# epoch 705
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4050 - policy_categorical_accuracy: 0.4070 - policy_loss: 2.2840 - value_loss: 0.1211 - value_mae: 0.2941
# epoch 706
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4142 - policy_categorical_accuracy: 0.4047 - policy_loss: 2.2941 - value_loss: 0.1201 - value_mae: 0.2923
# epoch 707
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - loss: 2.4222 - policy_categorical_accuracy: 0.4064 - policy_loss: 2.3029 - value_loss: 0.1194 - value_mae: 0.2912
# epoch 708
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4025 - policy_categorical_accuracy: 0.4107 - policy_loss: 2.2825 - value_loss: 0.1200 - value_mae: 0.2920
# epoch 709
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4150 - policy_categorical_accuracy: 0.4032 - policy_loss: 2.2946 - value_loss: 0.1203 - value_mae: 0.2931
# epoch 710
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4011 - policy_categorical_accuracy: 0.4081 - policy_loss: 2.2806 - value_loss: 0.1205 - value_mae: 0.2931
# epoch 711
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4140 - policy_categorical_accuracy: 0.4078 - policy_loss: 2.2930 - value_loss: 0.1210 - value_mae: 0.2938
# epoch 712
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4049 - policy_categorical_accuracy: 0.4063 - policy_loss: 2.2843 - value_loss: 0.1205 - value_mae: 0.2930
# epoch 713
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4288 - policy_categorical_accuracy: 0.4024 - policy_loss: 2.3075 - value_loss: 0.1212 - value_mae: 0.2945
# epoch 714
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4100 - policy_categorical_accuracy: 0.4048 - policy_loss: 2.2900 - value_loss: 0.1200 - value_mae: 0.2920
# epoch 715
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4046 - policy_categorical_accuracy: 0.4085 - policy_loss: 2.2844 - value_loss: 0.1202 - value_mae: 0.2925
# epoch 716
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.3895 - policy_categorical_accuracy: 0.4099 - policy_loss: 2.2690 - value_loss: 0.1206 - value_mae: 0.2932
# epoch 717
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4130 - policy_categorical_accuracy: 0.4051 - policy_loss: 2.2931 - value_loss: 0.1199 - value_mae: 0.2926
# epoch 718
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - loss: 2.4231 - policy_categorical_accuracy: 0.4055 - policy_loss: 2.3026 - value_loss: 0.1205 - value_mae: 0.2930
# epoch 719
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4176 - policy_categorical_accuracy: 0.4070 - policy_loss: 2.2968 - value_loss: 0.1208 - value_mae: 0.2937
# epoch 720
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - loss: 2.4244 - policy_categorical_accuracy: 0.4055 - policy_loss: 2.3034 - value_loss: 0.1210 - value_mae: 0.2941
# val = [2.419804096221924, 2.2995803356170654, 0.12023426592350006, 0.4069199860095978, 0.2925100028514862]
# Saved checkpoint at epoch 720
# epoch 721
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4113 - policy_categorical_accuracy: 0.4042 - policy_loss: 2.2925 - value_loss: 0.1188 - value_mae: 0.2900
# epoch 722
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.3929 - policy_categorical_accuracy: 0.4112 - policy_loss: 2.2738 - value_loss: 0.1192 - value_mae: 0.2912
# epoch 723
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4108 - policy_categorical_accuracy: 0.4089 - policy_loss: 2.2907 - value_loss: 0.1201 - value_mae: 0.2924
# epoch 724
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4057 - policy_categorical_accuracy: 0.4062 - policy_loss: 2.2859 - value_loss: 0.1198 - value_mae: 0.2921
# epoch 725
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4058 - policy_categorical_accuracy: 0.4035 - policy_loss: 2.2855 - value_loss: 0.1203 - value_mae: 0.2927
# epoch 726
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4195 - policy_categorical_accuracy: 0.4034 - policy_loss: 2.3008 - value_loss: 0.1187 - value_mae: 0.2900
# epoch 727
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4180 - policy_categorical_accuracy: 0.4036 - policy_loss: 2.2974 - value_loss: 0.1206 - value_mae: 0.2931
# epoch 728
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4101 - policy_categorical_accuracy: 0.4071 - policy_loss: 2.2904 - value_loss: 0.1197 - value_mae: 0.2917
# epoch 729
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4085 - policy_categorical_accuracy: 0.4092 - policy_loss: 2.2890 - value_loss: 0.1195 - value_mae: 0.2914
# epoch 730
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.3922 - policy_categorical_accuracy: 0.4074 - policy_loss: 2.2718 - value_loss: 0.1205 - value_mae: 0.2931
# epoch 731
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4053 - policy_categorical_accuracy: 0.4086 - policy_loss: 2.2851 - value_loss: 0.1202 - value_mae: 0.2931
# epoch 732
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4089 - policy_categorical_accuracy: 0.4074 - policy_loss: 2.2888 - value_loss: 0.1201 - value_mae: 0.2921
# epoch 733
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4132 - policy_categorical_accuracy: 0.4042 - policy_loss: 2.2934 - value_loss: 0.1198 - value_mae: 0.2919
# epoch 734
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4217 - policy_categorical_accuracy: 0.4065 - policy_loss: 2.3017 - value_loss: 0.1200 - value_mae: 0.2923
# epoch 735
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4017 - policy_categorical_accuracy: 0.4098 - policy_loss: 2.2803 - value_loss: 0.1213 - value_mae: 0.2949
# epoch 736
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4066 - policy_categorical_accuracy: 0.4051 - policy_loss: 2.2870 - value_loss: 0.1196 - value_mae: 0.2915
# epoch 737
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4237 - policy_categorical_accuracy: 0.4053 - policy_loss: 2.3047 - value_loss: 0.1190 - value_mae: 0.2908
# epoch 738
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4050 - policy_categorical_accuracy: 0.4055 - policy_loss: 2.2848 - value_loss: 0.1202 - value_mae: 0.2927
# epoch 739
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4240 - policy_categorical_accuracy: 0.4063 - policy_loss: 2.3038 - value_loss: 0.1203 - value_mae: 0.2925
# epoch 740
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4045 - policy_categorical_accuracy: 0.4061 - policy_loss: 2.2849 - value_loss: 0.1196 - value_mae: 0.2915
# val = [2.446979284286499, 2.326749324798584, 0.12023457139730453, 0.4032999873161316, 0.2925080955028534]
# Saved checkpoint at epoch 740
# epoch 741
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4223 - policy_categorical_accuracy: 0.4048 - policy_loss: 2.3016 - value_loss: 0.1207 - value_mae: 0.2933
# epoch 742
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4050 - policy_categorical_accuracy: 0.4084 - policy_loss: 2.2842 - value_loss: 0.1208 - value_mae: 0.2934
# epoch 743
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4186 - policy_categorical_accuracy: 0.4028 - policy_loss: 2.2983 - value_loss: 0.1203 - value_mae: 0.2926
# epoch 744
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4118 - policy_categorical_accuracy: 0.4109 - policy_loss: 2.2914 - value_loss: 0.1204 - value_mae: 0.2930
# epoch 745
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4023 - policy_categorical_accuracy: 0.4076 - policy_loss: 2.2816 - value_loss: 0.1207 - value_mae: 0.2937
# epoch 746
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4276 - policy_categorical_accuracy: 0.4060 - policy_loss: 2.3065 - value_loss: 0.1211 - value_mae: 0.2942
# epoch 747
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4036 - policy_categorical_accuracy: 0.4058 - policy_loss: 2.2839 - value_loss: 0.1197 - value_mae: 0.2919
# epoch 748
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4113 - policy_categorical_accuracy: 0.4079 - policy_loss: 2.2908 - value_loss: 0.1205 - value_mae: 0.2929
# epoch 749
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4020 - policy_categorical_accuracy: 0.4101 - policy_loss: 2.2814 - value_loss: 0.1206 - value_mae: 0.2938
# epoch 750
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.3965 - policy_categorical_accuracy: 0.4078 - policy_loss: 2.2762 - value_loss: 0.1203 - value_mae: 0.2929
# epoch 751
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - loss: 2.4058 - policy_categorical_accuracy: 0.4085 - policy_loss: 2.2856 - value_loss: 0.1203 - value_mae: 0.2927
# epoch 752
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.3875 - policy_categorical_accuracy: 0.4137 - policy_loss: 2.2672 - value_loss: 0.1202 - value_mae: 0.2924
# epoch 753
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4222 - policy_categorical_accuracy: 0.4025 - policy_loss: 2.3034 - value_loss: 0.1188 - value_mae: 0.2899
# epoch 754
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4305 - policy_categorical_accuracy: 0.4054 - policy_loss: 2.3096 - value_loss: 0.1210 - value_mae: 0.2945
# epoch 755
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4056 - policy_categorical_accuracy: 0.4052 - policy_loss: 2.2853 - value_loss: 0.1203 - value_mae: 0.2930
# epoch 756
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.3940 - policy_categorical_accuracy: 0.4165 - policy_loss: 2.2734 - value_loss: 0.1206 - value_mae: 0.2931
# epoch 757
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.3953 - policy_categorical_accuracy: 0.4090 - policy_loss: 2.2738 - value_loss: 0.1215 - value_mae: 0.2945
# epoch 758
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.3990 - policy_categorical_accuracy: 0.4083 - policy_loss: 2.2789 - value_loss: 0.1201 - value_mae: 0.2923
# epoch 759
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4319 - policy_categorical_accuracy: 0.4066 - policy_loss: 2.3107 - value_loss: 0.1212 - value_mae: 0.2942
# epoch 760
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4242 - policy_categorical_accuracy: 0.4027 - policy_loss: 2.3033 - value_loss: 0.1209 - value_mae: 0.2936
# val = [2.4236278533935547, 2.303400754928589, 0.12023551762104034, 0.4061799943447113, 0.2925104796886444]
# Saved checkpoint at epoch 760
# epoch 761
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4341 - policy_categorical_accuracy: 0.4027 - policy_loss: 2.3134 - value_loss: 0.1206 - value_mae: 0.2932
# epoch 762
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4117 - policy_categorical_accuracy: 0.4078 - policy_loss: 2.2917 - value_loss: 0.1200 - value_mae: 0.2929
# epoch 763
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - loss: 2.4142 - policy_categorical_accuracy: 0.4047 - policy_loss: 2.2930 - value_loss: 0.1212 - value_mae: 0.2942
# epoch 764
# 204/391 ━━━━━━━━━━━━━━━━━━━━ 6s 36ms/step - loss: 2.4194 - policy_categorical_accuracy: 0.4023 - policy_loss: 2.2980 - value_loss: 0.1215 - value_mae: 0.2945

# %%
model = keras.models.load_model(checkpoint_path)
print(f"Model loaded from {checkpoint_path}")
# Out:
# Model loaded from /content/drive/MyDrive/Master-2-IASD-app/Deep-learning/ResNet/checkpoints/model_last.keras

# %%
# Save the model to Google Drive
model_save_path = "/content/drive/MyDrive/Master-2-IASD-app/Deep-learning/ResNet/checkpoints/Mellissa_HAFIS-Ilona_LEDROGOFF-ResNet.h5"
model.save(model_save_path)
print(f"Model saved to {model_save_path}")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved to /content/drive/MyDrive/Master-2-IASD-app/Deep-learning/ResNet/checkpoints/Mellissa_HAFIS-Ilona_LEDROGOFF-ResNet.h5

# %%
model.save('Mellissa_HAFIS-Ilona_LEDROGOFF-v.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved as Mellissa_HAFIS-Ilona_LEDROGOFF-v12.h5

# %% [markdown]
# v3(40 epochs): gave same results approximatly 0.37
#
# v4 60 epochs:
# val = [2.61161470413208, 2.491255044937134, 0.12023338675498962, 0.3767400085926056, 0.29251644015312195]
#
#
# v5 80 epochs:
#
# val = [2.5814108848571777, 2.4611072540283203, 0.12023502588272095, 0.3830600082874298, 0.29250794649124146]
#
#
# v6 100 epochs:
# val = [2.563153028488159, 2.4429502487182617, 0.12023553997278214, 0.3858200013637543, 0.2925105392932892]
#
# v7 120 epochs
# :val = [2.5540621280670166, 2.433702230453491, 0.12023333460092545, 0.3862200081348419, 0.2925240397453308]
#
#
# v8 140 : val = [2.532742738723755, 2.4124836921691895, 0.12023456394672394, 0.38901999592781067, 0.2925328314304352]
#
# v9: 160 (learning rate passe a 0,0006):
# val = [2.5364038944244385, 2.4161550998687744, 0.1202331930398941, 0.38934001326560974, 0.292520672082901]
#
#
# v10 180 (learning rate passe a 0,0007):
# val = [2.5080697536468506, 2.3878350257873535, 0.12024098634719849, 0.39430001378059387, 0.2925296127796173]
#
# v11 200 epochs ; (learning rate passe a 0,0009)
# val = [2.4943742752075195, 2.374094247817993, 0.12023616582155228, 0.39452001452445984, 0.29251357913017273]
#
# v12 220 epochs ( 0.0009):
# val = [2.5123374462127686, 2.3920929431915283, 0.12023553997278214, 0.3924199938774109, 0.2925108075141907]
#
# v13 Saved checkpoint at epoch 440  ( learning rate 0.0009).
# val = [2.449185609817505, 2.3289377689361572, 0.1202370747923851, 0.4026600122451782, 0.2925172746181488]
#
#
# v14: Saved checkpoint at epoch 460 ( learning rate 0.0009).
# val = [2.4581916332244873, 2.337979555130005, 0.12023373693227768, 0.39937999844551086, 0.29251253604888916]
#
# val = [2.438472032546997, 2.3182597160339355, 0.12023499608039856, 0.40345999598503113, 0.29250776767730713]
# Saved checkpoint at epoch 520
#
# val = [2.4382171630859375, 2.318016529083252, 0.12024436891078949, 0.4046599864959717, 0.2925556004047394]
# Saved checkpoint at epoch 540
#
# val = [2.433934450149536, 2.313666582107544, 0.12023387849330902, 0.405239999294281, 0.2925293743610382]
# Saved checkpoint at epoch 560
#
# val = [2.4352598190307617, 2.315086841583252, 0.12023459374904633, 0.4044800102710724, 0.2925083339214325]
# Saved checkpoint at epoch 580
#
# val = [2.4337258338928223, 2.3134713172912598, 0.12024436146020889, 0.40303999185562134, 0.2925376892089844]
# Saved checkpoint at epoch 600
#
# val = [2.4322550296783447, 2.3120310306549072, 0.12023569643497467, 0.4032599925994873, 0.29251131415367126]
# Saved checkpoint at epoch 620
#
# val = [2.429220676422119, 2.3090097904205322, 0.12023370712995529, 0.4042600095272064, 0.2925277352333069]
# Saved checkpoint at epoch 640
#
# val = [2.432229518890381, 2.3119966983795166, 0.1202368512749672, 0.40478000044822693, 0.29251644015312195]
# Saved checkpoint at epoch 660
#
# val = [2.4379899501800537, 2.31775164604187, 0.12023387104272842, 0.4048199951648712, 0.292511910200119]
# Saved checkpoint at epoch 680
#
# val = [2.421626329421997, 2.301339626312256, 0.12023693323135376, 0.4053399860858917, 0.2925170063972473]
# Saved checkpoint at epoch 700
#
# val = [2.419804096221924, 2.2995803356170654, 0.12023426592350006, 0.4069199860095978, 0.2925100028514862]
# Saved checkpoint at epoch 720
#
# val = [2.446979284286499, 2.326749324798584, 0.12023457139730453, 0.4032999873161316, 0.2925080955028534]
# Saved checkpoint at epoch 740
#
# val = [2.4236278533935547, 2.303400754928589, 0.12023551762104034, 0.4061799943447113, 0.2925104796886444]
# Saved checkpoint at epoch 760
